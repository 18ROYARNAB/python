# %%
class Person:
    def __init__(self,name:str,age:int):
        self.name=name
        self.age=age
    def show(self):
        print(f"Person name : {self.name}, Age : {self.age}")

p1=Person("Arnab",19)
p1.show()
# Out:
# Person name : Arnab, Age : 19

# %%
class Car:
    def __init__(self,):
